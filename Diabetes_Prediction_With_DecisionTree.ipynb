# %% [markdown]
# Import Library

# %%
import pandas as pd
import pydotplus
from IPython.display import Image
from sklearn import tree

# %% [markdown]
# Show Dataset

# %%
data = pd.read_csv('diabetes.csv')
data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.loc[data['Pregnancies'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
data.loc[data['Glucose'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
data.loc[data['SkinThickness'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
data.loc[data['BloodPressure'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
data.loc[data['Insulin'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
data.loc[data['BMI'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
data.loc[data['Age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
data.loc[data['DiabetesPedigreeFunction'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
data.loc[data['Outcome'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
print(data.dtypes)
# Out:
# Pregnancies                 int64
# Glucose                     int64
# BloodPressure               int64
# SkinThickness               int64
# Insulin                     int64
# BMI                         int64
# DiabetesPedigreeFunction    int64
# Age                         int64
# Outcome                     int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
data['Pregnancies']=enc.fit_transform(data['Pregnancies'].values)
data['Glucose']=enc.fit_transform(data['Glucose'].values)
data['BloodPressure']=enc.fit_transform(data['BloodPressure'].values)
data['SkinThickness']=enc.fit_transform(data['SkinThickness'].values)
data['Insulin']=enc.fit_transform(data['Insulin'].values)
data['BMI']=enc.fit_transform(data['BMI'].values)
data['DiabetesPedigreeFunction']=enc.fit_transform(data['DiabetesPedigreeFunction'].values)
data['Age']=enc.fit_transform(data['Age'].values)
data['Outcome']=enc.fit_transform(data['Outcome'].values)


data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0            6       86             22             28        0  123
# 1            1       23             19             22        0   62
# 2            8      121             17              0        0   30
# 3            1       27             19             16       62   77
# 4            0       75              4             28      102  209
# 5            5       54             23              0        0   53
# 6            3       16              8             25       57  103
# 7           10       53              0              0        0  140
# 8            2      133             21             38      179   99
# 9            8       63             37              0        0    0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                       350   29        1
# 1                       196   10        0
# 2                       368   11        1
# 3                        53    0        0
# ...

# %% [markdown]
# Memisahkan variabel Independent dan Dependent

# %%
atr_data = data.drop(columns='Outcome')
atr_data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0            6       86             22             28        0  123
# 1            1       23             19             22        0   62
# 2            8      121             17              0        0   30
# 3            1       27             19             16       62   77
# 4            0       75              4             28      102  209
# 5            5       54             23              0        0   53
# 6            3       16              8             25       57  103
# 7           10       53              0              0        0  140
# 8            2      133             21             38      179   99
# 9            8       63             37              0        0    0
#
#    DiabetesPedigreeFunction  Age
# 0                       350   29
# 1                       196   10
# 2                       368   11
# 3                        53    0
# 4                       514   12
# ...

# %%
for column in data.columns:
    if data[column].dtype == 'object':
        data[column] = enc.fit_transform(data[column])

# %%
cls_data=data['Outcome']
cls_data.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %% [markdown]
# Training dan testing data

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(atr_data, cls_data, test_size=0.3, random_state=0)
tree_dataset = DecisionTreeClassifier(random_state=0)
tree_dataset.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
print('Nilai Akurasi:', tree_data.score(X_test, Y_test))
# Out:
# Nilai Akurasi: 0.7272727272727273

# %% [markdown]
# Visualisasi Data Decision Tree

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree_data, out_file='diabetes.dot', class_names= True, feature_names=atr_data.columns, impurity=False, filled=True)

# %%
data = datasets.load_diabetes()
X, y = data.data, data.target

# %%
clf = DecisionTreeClassifier()
clf.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
import graphviz
from sklearn.tree import export_graphviz
with open('diabetes.dot') as fig:
  dot_graph = fig.read()
  graphviz.Source(dot_graph).render('diabetes')

# %% [markdown]
# https://drive.google.com/file/d/1Qd6nMqZlYPFstHOar6I7nqb58kUfUQUI/view?usp=drive_link
